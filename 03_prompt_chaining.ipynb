# %%
from langgraph.graph import StateGraph, START, END
from langchain_openai import ChatOpenAI
from typing import TypedDict
from dotenv import load_dotenv

# %%
load_dotenv()
model = ChatOpenAI()

# %%
# create a state
class BlogState(TypedDict):
    title: str
    outline: str
    content: str

# %%
def create_outline(state: BlogState) -> BlogState:

    # fetch title
    title = state['title']

    # call llm gen outline
    prompt = f'Generate a detailed outline for a blog on the topic - {title}'
    outline = model.invoke(prompt).content

    # update state
    state['outline'] = outline

    return state

# %%
def create_blog(state: BlogState) -> BlogState:

    title = state['title']
    outline = state['outline']

    prompt = f'Write a detailed blog on the title - {title} using the follwing outline \n {outline}'

    content = model.invoke(prompt).content

    state['content'] = content

    return state

# %%
graph = StateGraph(BlogState)

# nodes
graph.add_node('create_outline', create_outline)
graph.add_node('create_blog', create_blog)

# edges
graph.add_edge(START, 'create_outline')
graph.add_edge('create_outline', 'create_blog')
graph.add_edge('create_blog', END)

workflow = graph.compile()

# %%
intial_state = {'title': 'Rise of AI in India'}

final_state = workflow.invoke(intial_state)

print(final_state['outline'])
# Out:
# I. Introduction
#     A. Brief explanation of AI and its importance
#     B. Overview of the rise of AI in India
#     C. Thesis statement: AI is becoming increasingly prominent in India and is transforming various industries
#
# II. Historical perspective of AI in India
#     A. Evolution of AI technology in India
#     B. Early adoption of AI in Indian companies
#     C. Government initiatives to promote AI research and development
#
# III. Current status of AI in India
#     A. Growth of AI startups in India
#     B. Application of AI in different industries such as healthcare, finance, agriculture, etc.
#     C. Collaboration between Indian companies and international tech giants in the field of AI
#
# IV. Challenges and opportunities for AI in India
#     A. Skills gap in AI talent in India
#     B. Data privacy and security concerns
#     C. Potential for AI to drive economic growth and innovation in India
#     D. Ethical implications of AI deployment in Indian society
#
# V. Case studies of successful AI implementation in India
#     A. Use of AI in healthcare by companies like Practo and SigTuple
#     B. AI-driven financial services offered by companies like ZestMoney and Rupeek
#     C. Agricultural applications of AI by startups like CropIn and SatSure
#
# VI. Future outlook for AI in India
#     A. Predictions for the growth of AI industry in India
#     B. Potential impact of AI on the Indian job market
#     C. Role of government and regulatory bodies in shaping the future of AI in India
#
# VII. Conclusion
#     A. Recap of key points discussed in the blog
#     B. Importance of AI in driving technological advancements in India
#     C. Call to action for individuals and businesses to embrace AI technology in India's digital transformation.

# %%
print(final_state['content'])
# Out:
# AI, or Artificial Intelligence, is rapidly transforming industries around the world by revolutionizing the way businesses operate and making tasks more efficient. In India, the rise of AI is evident in the increasing adoption of AI technology by companies across various sectors. In this blog, we will delve into the historical perspective of AI in India, the current status of AI in the country, the challenges and opportunities it presents, case studies of successful AI implementation, the future outlook for AI in India, and the importance of embracing AI technology in India's digital transformation.
#
# Historical perspective of AI in India:
#
# The evolution of AI technology in India can be traced back to the early 2000s when Indian companies started exploring the potential of AI to improve business operations. Companies like Infosys and TCS were early adopters of AI technology and invested in developing AI capabilities to enhance their services.
#
# The Indian government has also played a significant role in promoting AI research and development in the country. Initiatives like the National Programme on AI, launched by NITI Aayog in 2018, aim to accelerate AI adoption in various sectors by facilitating collaboration between industry, academia, and government.
#
# Current status of AI in India:
#
# The growth of AI startups in India is a testament to the increasing interest and investment in AI technology. Companies like Freshworks, Haptik, and InMobi are leading the way in developing AI-powered solutions for customer service, marketing, and advertising.
#
# AI is being applied across various industries in India, including healthcare, finance, agriculture, and manufacturing. Healthcare companies like Practo and SigTuple are using AI for medical imaging analysis and patient diagnosis, while financial services startups like ZestMoney and Rupeek are leveraging AI for credit scoring and loan processing.
#
# Collaboration between Indian companies and international tech giants like Google, Microsoft, and IBM is also driving the growth of AI in India. These partnerships are enabling Indian companies to access cutting-edge AI technologies and expertise to further enhance their products and services.
#
# Challenges and opportunities for AI in India:
#
# Despite the rapid growth of AI in India, the country faces challenges in terms of the skills gap in AI talent, data privacy and security concerns, and the ethical implications of AI deployment. Addressing these challenges will be crucial for ensuring the responsible and sustainable growth of AI in India.
#
# However, the opportunities presented by AI are immense, with the potential for AI to drive economic growth and innovation in India. By embracing AI technology, Indian businesses can improve efficiency, enhance customer experiences, and unlock new revenue streams.
#
# Case studies of successful AI implementation in India:
#
# Several Indian companies have successfully implemented AI technology to improve their operations and services. For example, Practo uses AI algorithms to analyze medical images and aid in accurate diagnosis, while companies like CropIn and SatSure are using AI for precision agriculture to optimize crop yields and reduce environmental impact.
#
# Future outlook for AI in India:
#
# The future of AI in India looks promising, with predictions for the growth of the AI industry in the country. AI is expected to have a significant impact on the Indian job market, with automation and AI-powered technologies reshaping the workforce and creating new job opportunities in AI-related fields.
#
# The role of the government and regulatory bodies will be crucial in shaping the future of AI in India by establishing guidelines for the ethical deployment of AI technologies and fostering collaboration between industry stakeholders.
#
# In conclusion, the rise of AI in India is transforming industries and driving technological advancements in the country. It is essential for individuals and businesses to embrace AI technology to stay competitive in a rapidly evolving digital landscape. By harnessing the power of AI, India can pave the way for innovation, economic growth, and societal progress in the years to come.

# %%
print(final_state['title'])
# Out:
# Rise of AI in India
